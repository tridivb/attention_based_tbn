# %% [markdown]
# #### TBN Results
# <!-- <style>
# table, th, td {
#   border: 1px solid white;
# }
# </style> -->
# <table style="width:100%">
#   <tr>
#     <th>Dataset</th>
#     <th>Method</th>
#     <th>Verb (Top-1)</th>
#     <th>Noun (Top-1)</th>
#     <th>Action (Top-1)</th>
#     <th>Verb (Top-5)</th>
#     <th>Noun (Top-5)</th>
#     <th>Action (Top-5)</th>
#   </tr>
#   <tr>
#     <td rowspan=7 align="center">Validation Seen</td>
#     <td align="center">RGB</td>
#     <td align="center">48.85</td>
#     <td align="center">39.24</td>
#     <td align="center">22.89</td>
#     <td align="center">85.85</td>
#     <td align="center">63.02</td>
#     <td align="center">57.06</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">55.93</td>
#     <td align="center">31.42</td>
#     <td align="center">21.49</td>
#     <td align="center">84.75</td>
#     <td align="center">55.29</td>
#     <td align="center">50.09</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">44.39</td>
#     <td align="center">21.92</td>
#     <td align="center">15.16</td>
#     <td align="center">75.75</td>
#     <td align="center">40.42</td>
#     <td align="center">35.6</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">57.91</td>
#     <td align="center">41.81</td>
#     <td align="center">29.99</td>
#     <td align="center">88.18</td>
#     <td align="center">65.61</td>
#     <td align="center">61.0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Audio</td>
#     <td align="center">56.19</td>
#     <td align="center">40.97</td>
#     <td align="center">27.15</td>
#     <td align="center">85.26</td>
#     <td align="center">65.01</td>
#     <td align="center">58.12</td>
#   </tr>
#   <tr>
#     <td align="center">Flow+Audio</td>
#     <td align="center">55.68</td>
#     <td align="center">29.69</td>
#     <td align="center">22.05</td>
#     <td align="center">83.46</td>
#     <td align="center">51.91</td>
#     <td align="center">47.38</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">57.75</td>
#     <td align="center">39.57</td>
#     <td align="center">27.49</td>
#     <td align="center">85.48</td>
#     <td align="center">62.55</td>
#     <td align="center">56.26</td>
#   </tr>
#   <tr>
#     <td rowspan=7 align="center">Validation Unseen</td>
#     <td align="center">RGB</td>
#     <td align="center">35.05</td>
#     <td align="center">19.01</td>
#     <td align="center">8.72</td>
#     <td align="center">76.97</td>
#     <td align="center">39.97</td>
#     <td align="center">33.7</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">44.27</td>
#     <td align="center">17.42</td>
#     <td align="center">11.02</td>
#     <td align="center">78.4</td>
#     <td align="center">37.62</td>
#     <td align="center">32.58</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">28.14</td>
#     <td align="center">9.13</td>
#     <td align="center">4.59</td>
#     <td align="center">57.08</td>
#     <td align="center">20.87</td>
#     <td align="center">15.78</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">45.6</td>
#     <td align="center">20.29</td>
#     <td align="center">12.14</td>
#     <td align="center">79.54</td>
#     <td align="center">43.09</td>
#     <td align="center">37.17</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Audio</td>
#     <td align="center">35.53</td>
#     <td align="center">17.99</td>
#     <td align="center">7.98</td>
#     <td align="center">68.54</td>
#     <td align="center">38.78</td>
#     <td align="center">29.61</td>
#   </tr>
#   <tr>
#     <td align="center">Flow+Audio</td>
#     <td align="center">38.97</td>
#     <td align="center">13.66</td>
#     <td align="center">7.06</td>
#     <td align="center">68.68</td>
#     <td align="center">29.26</td>
#     <td align="center">23.48</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">42.2</td>
#     <td align="center">19.53</td>
#     <td align="center">10.57</td>
#     <td align="center">74.71</td>
#     <td align="center">38.86</td>
#     <td align="center">32.01</td>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Test Seen</td>
#     <td align="center">RGB</td>
#     <td align="center">49.91</td>
#     <td align="center">38.73</td>
#     <td align="center">24.39</td>
#     <td align="center">86.88</td>
#     <td align="center">63.80</td>
#     <td align="center">42.89</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">55.46</td>
#     <td align="center">28.57</td>
#     <td align="center">19.42</td>
#     <td align="center">85.95</td>
#     <td align="center">52.12</td>
#     <td align="center">36.26</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">44.05</td>
#     <td align="center">21.35</td>
#     <td align="center">13.68</td>
#     <td align="center">75.95</td>
#     <td align="center">42.26</td>
#     <td align="center">25.71</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">58.63</td>
#     <td align="center">41.44</td>
#     <td align="center">29.81</td>
#     <td align="center">88.73</td>
#     <td align="center">66.57</td>
#     <td align="center">48.64</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">57.40</td>
#     <td align="center">38.70</td>
#     <td align="center">27.20</td>
#     <td align="center">85.26</td>
#     <td align="center">62.68</td>
#     <td align="center">46.34</td>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Test Unseen</td>
#     <td align="center">RGB</td>
#     <td align="center">36.77</td>
#     <td align="center">20.55</td>
#     <td align="center">10.89</td>
#     <td align="center">72.55</td>
#     <td align="center">43.70</td>
#     <td align="center">22.50</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">46.36</td>
#     <td align="center">20.93</td>
#     <td align="center">13.08</td>
#     <td align="center">76.31</td>
#     <td align="center">41.21</td>
#     <td align="center">25.06</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">32.26</td>
#     <td align="center">11.20</td>
#     <td align="center">4.92</td>
#     <td align="center">64.70</td>
#     <td align="center">27.45</td>
#     <td align="center">12.84</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">45.85</td>
#     <td align="center">24.55</td>
#     <td align="center">15.43</td>
#     <td align="center">76.48</td>
#     <td align="center">47.32</td>
#     <td align="center">28.58</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">45.95</td>
#     <td align="center">22.91</td>
#     <td align="center">13.90</td>
#     <td align="center">74.80</td>
#     <td align="center">44.49</td>
#     <td align="center">27.38</td>
#   </tr>
# </table>

# %% [markdown]
# #### RGB
# **Train** \
# <img src="images/rgb_train.png"> \
# **Validation** \
# <img src="images/rgb_val.png">

# %% [markdown]
# #### Flow
# **Train** \
# <img src="images/flow_train.png"> \
# **Validation** \
# <img src="images/flow_val.png">

# %% [markdown]
# #### Audio
# **Train** \
# <img src="images/audio_train.png"> \
# **Validation** \
# <img src="images/audio_val.png">

# %% [markdown]
# #### RGB_Flow
# **Train** \
# <img src="images/rgb_flow_train.png"> \
# **Validation** \
# <img src="images/rgb_flow_val.png">

# %% [markdown]
# #### RGB_Audio
# **Train** \
# <img src="images/rgb_audio_train.png"> \
# **Validation** \
# <img src="images/rgb_audio_val.png">

# %% [markdown]
# #### Flow_Audio
# **Train** \
# <img src="images/flow_audio_train.png"> \
# **Validation** \
# <img src="images/flow_audio_val.png">

# %% [markdown]
# #### RGB_Flow_Audio
# **Train** \
# <img src="images/rgb_flow_audio_train.png"> \
# **Validation** \
# <img src="images/rgb_flow_audio_val.png">
