# %% [markdown]
# #### TBN Results
# <!-- <style>
# table, th, td {
#   border: 1px solid white;
# }
# </style> -->
# <table style="width:100%">
#   <tr>
#     <th>Dataset</th>
#     <th>Method</th>
#     <th>Verb (Top-1)</th>
#     <th>Noun (Top-1)</th>
#     <th>Action (Top-1)</th>
#     <th>Verb (Top-5)</th>
#     <th>Noun (Top-5)</th>
#     <th>Action (Top-5)</th>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Validation Seen</td>
#     <td align="center">RGB</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Validation Unseen</td>
#     <td align="center">RGB</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Test Seen</td>
#     <td align="center">RGB</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td rowspan=5 align="center">Test Unseen</td>
#     <td align="center">RGB</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
#   <tr>
#     <td align="center">RGB+Flow+Audio</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#     <td align="center">0</td>
#   </tr>
# </table>
